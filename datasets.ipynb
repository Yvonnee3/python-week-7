# %%
#Load and Explore the Dataset

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
# Load Iris dataset
try:
    iris_data = load_iris(as_frame=True)
    df = iris_data.frame
except Exception as e:
    print("Error loading dataset:", e)

# %%
# Display first few rows
print("\n First 5 rows:")
print(df.head())
# Out:
#  First 5 rows:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Data structure
print("\n Data Types:")
print(df.dtypes)
# Out:
#  Data Types:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int64
# dtype: object

# %%
# Check for missing values
print("\n Missing Values:")
print(df.isnull().sum())
# Out:
#  Missing Values:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
# Clean the data 
df_cleaned = df.dropna()

# %%
# Task 2: Basic Data Analysis

# Describe numerical columns
print("\n Basic Statistics:")
print(df_cleaned.describe())
# Out:
#  Basic Statistics:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
# Group by species and compute mean for each group
print("\n Mean measurements per species:")
print(df_cleaned.groupby('target').mean())
# Out:
#  Mean measurements per species:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# 0                   5.006             3.428              1.462
# 1                   5.936             2.770              4.260
# 2                   6.588             2.974              5.552
#
#         petal width (cm)
# target
# 0                  0.246
# 1                  1.326
# 2                  2.026

# %%
# Rename target values for clarity
df_cleaned['species'] = df_cleaned['target'].map(dict(zip(range(3), iris_data.target_names)))

# %%
#  Task 3: Data Visualization

# 1. Line chart: sepal length across index (to simulate time series)
plt.figure(figsize=(10, 5))
for species in df_cleaned['species'].unique():
    subset = df_cleaned[df_cleaned['species'] == species]
    plt.plot(subset.index, subset['sepal length (cm)'], label=species)
plt.title('Line Chart: Sepal Length Over Index')
plt.xlabel('Index')
plt.ylabel('Sepal Length (cm)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# 2. Bar chart: average petal length per species
plt.figure(figsize=(8, 5))
sns.barplot(data=df_cleaned, x='species', y='petal length (cm)', ci=None)
plt.title('Bar Chart: Avg Petal Length per Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1278/3176912281.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df_cleaned, x='species', y='petal length (cm)', ci=None)

# %%
# 3. Histogram: distribution of sepal width
plt.figure(figsize=(8, 5))
sns.histplot(df_cleaned['sepal width (cm)'], bins=15, kde=True)
plt.title('Histogram: Sepal Width Distribution')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 4. Scatter plot: sepal vs petal length
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df_cleaned, x='sepal length (cm)', y='petal length (cm)', hue='species')
plt.title('Scatter Plot: Sepal vs Petal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#  Findings

# - Setosa flowers have smaller petal length and shorter sepal length.
# - Versicolor and Virginica overlap slightly in size but Virginica is generally larger.
# - Sepal width follows a normal-like distribution.
# - Strong correlation observed between petal and sepal length.

# %%
import os
print(os.getcwd(
# Out:
#   Cell In[16], line 2
#     print(os.getcwd(
#                     ^
# SyntaxError: incomplete input

# %%
import os
print(os.getcwd())
# Out:
# /home/4c749fce-06bf-4484-8e66-bb18a0dea3e1/week 7 python
